# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielCadavid/InteligenciaArtificial/blob/main/K_Nearest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #K-Nearest
# Es un modelo que sirve para hacer predicciones de una nueva entrada, para la cual el modelo ya ha sido entrenado con un set de datos
# ##Clasificacion
# >Es la version mas sencilla, donde solo se considera un vecino, el modelo entrenado es capaz de decir que tan cercano es la entrada a un punto del modelo

# %%
# !pip3 install mglearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn

# %%
mglearn.plots.plot_knn_classification(n_neighbors=1)
